# %% [markdown]
# ## Visualização de Variáveis e textos

# %% [markdown]
# Concatenação

# %%
print("Conhecendo o comando Print")

x = 8
print(x)
# Out:
# Conhecendo o comando Print
# 8

# %%
x = 10
y = 5
print (x+y)
# Out:
# 15

# %%
nome = 'Raquel Luz'
y = 34
print("Meu nome é ", nome, "e minha idade é ", y)
# Out:
# Meu nome é  Raquel Luz e minha idade é  34

# %%
y = 10; z = 20 + x - y

print('Declarar variáveis na mesma linha:', y,',',z)
# Out:
# Declarar variáveis na mesma linha: 10 , 20

# %% [markdown]
# Type

# %%
x=10
type(x)
print('x', type(x))

nome='Raquel'
print('nome, type(nome)')
# Out:
# x <class 'int'>
# nome, type(nome)

# %% [markdown]
# Input
# - Armazenar informações digitadas pelo usuário em uma variável

# %%
nome = input(("Digite o nome do usuário "))
print(nome)
# Out:
# Digite o nome do usuárioRaquel
# Raquel

# %%
ano_nascimento = input("Digite o ano que nasceu ")
print(ano_nascimento)
# Out:
# Digite o ano que nasceu 1990
# 1990

# %%
ano_atual = input('Digite o ano atual ')
print(ano_atual)
# Out:
# Digite o ano atual 2024
# 2024

# %%
idade = int(ano_atual) - int(ano_nascimento)
print('Sua idade é:', idade)
# Out:
# Sua idade é: 34
